# %%
# !pip install -U git+https://github.com/huggingface/diffusers.git

# %%
# !pip install -U controlnet_aux==0.0.7

# %%
# !pip install transformers accelerate safetensors mediapipe
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Collecting git+https://github.com/huggingface/diffusers.git
#   Cloning https://github.com/huggingface/diffusers.git to c:\users\platinum\appdata\local\temp\pip-req-build-pvqj2k4j
#   Resolved https://github.com/huggingface/diffusers.git to commit 63b684684979b22d9cfbeacc534c2f274e95e3ab
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: importlib-metadata in c:\users\platinum\anaconda3\envs\cuda_venv\lib\site-packages (from diffusers==0.28.0.dev0) (6.8.0)
# Requirement already satisfied: filelock in c:\users\platinum\anaconda3\envs\cuda_venv\lib\site-packages (from diffusers==0.28.0.dev0) (3.12.4)
# Collecting huggingface-hub>=0.20.2 (from diffusers==0.28.0.dev0)
#   Downloading huggingface_hub-0.21.4-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: numpy in c:\users\platinum\anaconda3\envs\cuda_venv\lib\site-packages (from diffusers==0.28.0.dev0) (1.26.0)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\platinum\anaconda3\envs\cuda_venv\lib\site-packages (from diffusers==0.28.0.dev0) (2023.10.3)
# Requirement already satisfied: requests in c:\users\platinum\anaconda3\envs\cuda_venv\lib\site-packages (from diffusers==0.28.0.dev0) (2.31.0)
# Requirement already satisfied: safetensors>=0.3.1 in c:\users\platinum\anaconda3\envs\cuda_venv\lib\site-packages (from diffusers==0.28.0.dev0) (0.4.0)
# Requirement already satisfied: Pillow in c:\users\platinum\anaconda3\envs\cuda_venv\lib\site-packages (from diffusers==0.28.0.dev0) (10.0.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\platinum\anaconda3\envs\cuda_venv\lib\site-packages (from huggingface-hub>=0.20.2->diffusers==0.28.0.dev0) (2023.10.0)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\platinum\anaconda3\envs\cuda_venv\lib\site-packages (from huggingface-hub>=0.20.2->diffusers==0.28.0.dev0) (4.66.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\platinum\anaconda3\envs\cuda_venv\lib\site-packages (from huggingface-hub>=0.20.2->diffusers==0.28.0.dev0) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\platinum\anaconda3\envs\cuda_venv\lib\site-packages (from huggingface-hub>=0.20.2->diffusers==0.28.0.dev0) (4.7.1)
# Requirement already satisfied: packaging>=20.9 in c:\users\platinum\anaconda3\envs\cuda_venv\lib\site-packages (from huggingface-hub>=0.20.2->diffusers==0.28.0.dev0) (23.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\platinum\anaconda3\envs\cuda_venv\lib\site-packages (from importlib-metadata->diffusers==0.28.0.dev0) (3.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\platinum\anaconda3\envs\cuda_venv\lib\site-packages (from requests->diffusers==0.28.0.dev0) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\platinum\anaconda3\envs\cuda_venv\lib\site-packages (from requests->diffusers==0.28.0.dev0) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\platinum\anaconda3\envs\cuda_venv\lib\site-packages (from requests->diffusers==0.28.0.dev0) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\platinum\anaconda3\envs\cuda_venv\lib\site-packages (from requests->diffusers==0.28.0.dev0) (2023.7.22)
# Requirement already satisfied: colorama in c:\users\platinum\anaconda3\envs\cuda_venv\lib\site-packages (from tqdm>=4.42.1->huggingface-hub>=0.20.2->diffusers==0.28.0.dev0) (0.4.6)
# Downloading huggingface_hub-0.21.4-py3-none-any.whl (346 kB)
#    ---------------------------------------- 0.0/346.4 kB ? eta -:--:--
#    ---------------------------------------- 0.0/346.4 kB ? eta -:--:--
#    - -------------------------------------- 10.2/346.4 kB ? eta -:--:--
#    - -------------------------------------- 10.2/346.4 kB ? eta -:--:--
#    - -------------------------------------- 10.2/346.4 kB ? eta -:--:--
#    - -------------------------------------- 10.2/346.4 kB ? eta -:--:--
#    --- ----------------------------------- 30.7/346.4 kB 119.1 kB/s eta 0:00:03
#    --- ----------------------------------- 30.7/346.4 kB 119.1 kB/s eta 0:00:03
#    --- ----------------------------------- 30.7/346.4 kB 119.1 kB/s eta 0:00:03
#    --- ----------------------------------- 30.7/346.4 kB 119.1 kB/s eta 0:00:03
#    --- ----------------------------------- 30.7/346.4 kB 119.1 kB/s eta 0:00:03
#    --- ----------------------------------- 30.7/346.4 kB 119.1 kB/s eta 0:00:03
#    ---- ----------------------------------- 41.0/346.4 kB 70.3 kB/s eta 0:00:05
#    ------- -------------------------------- 61.4/346.4 kB 96.4 kB/s eta 0:00:03
#    ------- -------------------------------- 61.4/346.4 kB 96.4 kB/s eta 0:00:03
#    -------- ------------------------------ 71.7/346.4 kB 100.9 kB/s eta 0:00:03
#    -------- ------------------------------ 71.7/346.4 kB 100.9 kB/s eta 0:00:03
#    ---------- ---------------------------- 92.2/346.4 kB 119.2 kB/s eta 0:00:03
#    ---------- ---------------------------- 92.2/346.4 kB 119.2 kB/s eta 0:00:03
#    ---------- ---------------------------- 92.2/346.4 kB 119.2 kB/s eta 0:00:03

#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface-hub 0.17.3
#     Uninstalling huggingface-hub-0.17.3:
#       Successfully uninstalled huggingface-hub-0.17.3
#   Attempting uninstall: diffusers
#     Found existing installation: diffusers 0.22.0.dev0
#     Uninstalling diffusers-0.22.0.dev0:
#       Successfully uninstalled diffusers-0.22.0.dev0
# Successfully installed diffusers-0.28.0.dev0 huggingface-hub-0.21.4
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/diffusers.git 'C:\Users\Platinum\AppData\Local\Temp\pip-req-build-pvqj2k4j'
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tokenizers 0.14.1 requires huggingface_hub<0.18,>=0.16.4, but you have huggingface-hub 0.21.4 which is incompatible.
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Requirement already satisfied: controlnet_aux==0.0.7 in c:\users\platinum\anaconda3\envs\cuda_venv\lib\site-packages (0.0.7)
# Requirement already satisfied: torch in c:\users\platinum\anaconda3\envs\cuda_venv\lib\site-packages (from controlnet_aux==0.0.7) (2.1.0)
# Requirement already satisfied: importlib-metadata in c:\users\platinum\anaconda3\envs\cuda_venv\lib\site-packages (from controlnet_aux==0.0.7) (6.8.0)
# Requirement already satisfied: huggingface-hub in c:\users\platinum\anaconda3\envs\cuda_venv\lib\site-packages (from controlnet_aux==0.0.7) (0.21.4)
# Requirement already satisfied: scipy in c:\users\platinum\anaconda3\envs\cuda_venv\lib\site-packages (from controlnet_aux==0.0.7) (1.11.3)
# Requirement already satisfied: opencv-python in c:\users\platinum\anaconda3\envs\cuda_venv\lib\site-packages (from controlnet_aux==0.0.7) (4.8.1.78)
# Requirement already satisfied: filelock in c:\users\platinum\anaconda3\envs\cuda_venv\lib\site-packages (from controlnet_aux==0.0.7) (3.12.4)
# Requirement already satisfied: numpy in c:\users\platinum\anaconda3\envs\cuda_venv\lib\site-packages (from controlnet_aux==0.0.7) (1.26.0)
# Requirement already satisfied: Pillow in c:\users\platinum\anaconda3\envs\cuda_venv\lib\site-packages (from controlnet_aux==0.0.7) (10.0.1)
# Requirement already satisfied: einops in c:\users\platinum\anaconda3\envs\cuda_venv\lib\site-packages (from controlnet_aux==0.0.7) (0.7.0)
# Requirement already satisfied: torchvision in c:\users\platinum\anaconda3\envs\cuda_venv\lib\site-packages (from controlnet_aux==0.0.7) (0.16.0)
# Requirement already satisfied: timm in c:\users\platinum\anaconda3\envs\cuda_venv\lib\site-packages (from controlnet_aux==0.0.7) (0.9.8)
# Requirement already satisfied: scikit-image in c:\users\platinum\anaconda3\envs\cuda_venv\lib\site-packages (from controlnet_aux==0.0.7) (0.22.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\platinum\anaconda3\envs\cuda_venv\lib\site-packages (from huggingface-hub->controlnet_aux==0.0.7) (2023.10.0)
# Requirement already satisfied: requests in c:\users\platinum\anaconda3\envs\cuda_venv\lib\site-packages (from huggingface-hub->controlnet_aux==0.0.7) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\platinum\anaconda3\envs\cuda_venv\lib\site-packages (from huggingface-hub->controlnet_aux==0.0.7) (4.66.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\platinum\anaconda3\envs\cuda_venv\lib\site-packages (from huggingface-hub->controlnet_aux==0.0.7) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\platinum\anaconda3\envs\cuda_venv\lib\site-packages (from huggingface-hub->controlnet_aux==0.0.7) (4.7.1)
# Requirement already satisfied: packaging>=20.9 in c:\users\platinum\anaconda3\envs\cuda_venv\lib\site-packages (from huggingface-hub->controlnet_aux==0.0.7) (23.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\platinum\anaconda3\envs\cuda_venv\lib\site-packages (from importlib-metadata->controlnet_aux==0.0.7) (3.17.0)
# Requirement already satisfied: networkx>=2.8 in c:\users\platinum\anaconda3\envs\cuda_venv\lib\site-packages (from scikit-image->controlnet_aux==0.0.7) (3.1)
# Requirement already satisfied: imageio>=2.27 in c:\users\platinum\anaconda3\envs\cuda_venv\lib\site-packages (from scikit-image->controlnet_aux==0.0.7) (2.31.6)
# Requirement already satisfied: tifffile>=2022.8.12 in c:\users\platinum\anaconda3\envs\cuda_venv\lib\site-packages (from scikit-image->controlnet_aux==0.0.7) (2023.9.26)
# Requirement already satisfied: lazy_loader>=0.3 in c:\users\platinum\anaconda3\envs\cuda_venv\lib\site-packages (from scikit-image->controlnet_aux==0.0.7) (0.3)
# Requirement already satisfied: safetensors in c:\users\platinum\anaconda3\envs\cuda_venv\lib\site-packages (from timm->controlnet_aux==0.0.7) (0.4.0)
# Requirement already satisfied: sympy in c:\users\platinum\anaconda3\envs\cuda_venv\lib\site-packages (from torch->controlnet_aux==0.0.7) (1.11.1)
# Requirement already satisfied: jinja2 in c:\users\platinum\anaconda3\envs\cuda_venv\lib\site-packages (from torch->controlnet_aux==0.0.7) (3.1.2)
# Requirement already satisfied: colorama in c:\users\platinum\anaconda3\envs\cuda_venv\lib\site-packages (from tqdm>=4.42.1->huggingface-hub->controlnet_aux==0.0.7) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\platinum\anaconda3\envs\cuda_venv\lib\site-packages (from jinja2->torch->controlnet_aux==0.0.7) (2.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\platinum\anaconda3\envs\cuda_venv\lib\site-packages (from requests->huggingface-hub->controlnet_aux==0.0.7) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\platinum\anaconda3\envs\cuda_venv\lib\site-packages (from requests->huggingface-hub->controlnet_aux==0.0.7) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\platinum\anaconda3\envs\cuda_venv\lib\site-packages (from requests->huggingface-hub->controlnet_aux==0.0.7) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\platinum\anaconda3\envs\cuda_venv\lib\site-packages (from requests->huggingface-hub->controlnet_aux==0.0.7) (2023.7.22)
# Requirement already satisfied: mpmath>=0.19 in c:\users\platinum\anaconda3\envs\cuda_venv\lib\site-packages (from sympy->torch->controlnet_aux==0.0.7) (1.3.0)
# Could not fetch URL https://pypi.ngc.nvidia.com/pip/: There was a problem confirming the ssl certificate: HTTPSConnectionPool(host='pypi.ngc.nvidia.com', port=443): Max retries exceeded with url: /pip/ (Caused by SSLError(SSLEOFError(8, '[SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1006)'))) - skipping
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Requirement already satisfied: transformers in c:\users\platinum\anaconda3\envs\cuda_venv\lib\site-packages (4.34.1)
# Requirement already satisfied: accelerate in c:\users\platinum\anaconda3\envs\cuda_venv\lib\site-packages (0.24.0)
# Requirement already satisfied: safetensors in c:\users\platinum\anaconda3\envs\cuda_venv\lib\site-packages (0.4.0)
# Requirement already satisfied: mediapipe in c:\users\platinum\appdata\roaming\python\python311\site-packages (0.10.7)
# Requirement already satisfied: filelock in c:\users\platinum\anaconda3\envs\cuda_venv\lib\site-packages (from transformers) (3.12.4)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in c:\users\platinum\anaconda3\envs\cuda_venv\lib\site-packages (from transformers) (0.21.4)
# Requirement already satisfied: numpy>=1.17 in c:\users\platinum\anaconda3\envs\cuda_venv\lib\site-packages (from transformers) (1.26.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\platinum\anaconda3\envs\cuda_venv\lib\site-packages (from transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\platinum\anaconda3\envs\cuda_venv\lib\site-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\platinum\anaconda3\envs\cuda_venv\lib\site-packages (from transformers) (2023.10.3)
# Requirement already satisfied: requests in c:\users\platinum\anaconda3\envs\cuda_venv\lib\site-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.15,>=0.14 in c:\users\platinum\anaconda3\envs\cuda_venv\lib\site-packages (from transformers) (0.14.1)
# Requirement already satisfied: tqdm>=4.27 in c:\users\platinum\anaconda3\envs\cuda_venv\lib\site-packages (from transformers) (4.66.1)
# Requirement already satisfied: psutil in c:\users\platinum\anaconda3\envs\cuda_venv\lib\site-packages (from accelerate) (5.9.0)
# Requirement already satisfied: torch>=1.10.0 in c:\users\platinum\anaconda3\envs\cuda_venv\lib\site-packages (from accelerate) (2.1.0)
# Requirement already satisfied: absl-py in c:\users\platinum\appdata\roaming\python\python311\site-packages (from mediapipe) (2.0.0)
# Requirement already satisfied: attrs>=19.1.0 in c:\users\platinum\anaconda3\envs\cuda_venv\lib\site-packages (from mediapipe) (23.1.0)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\platinum\anaconda3\envs\cuda_venv\lib\site-packages (from mediapipe) (23.5.26)
# Requirement already satisfied: matplotlib in c:\users\platinum\appdata\roaming\python\python311\site-packages (from mediapipe) (3.8.0)
# Requirement already satisfied: opencv-contrib-python in c:\users\platinum\appdata\roaming\python\python311\site-packages (from mediapipe) (4.8.1.78)
# Requirement already satisfied: protobuf<4,>=3.11 in c:\users\platinum\anaconda3\envs\cuda_venv\lib\site-packages (from mediapipe) (3.20.3)
# Requirement already satisfied: sounddevice>=0.4.4 in c:\users\platinum\appdata\roaming\python\python311\site-packages (from mediapipe) (0.4.6)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\platinum\anaconda3\envs\cuda_venv\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (2023.10.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\platinum\anaconda3\envs\cuda_venv\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (4.7.1)
# Requirement already satisfied: CFFI>=1.0 in c:\users\platinum\anaconda3\envs\cuda_venv\lib\site-packages (from sounddevice>=0.4.4->mediapipe) (1.15.1)
# Collecting huggingface-hub<1.0,>=0.16.4 (from transformers)
#   Downloading huggingface_hub-0.17.3-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: sympy in c:\users\platinum\anaconda3\envs\cuda_venv\lib\site-packages (from torch>=1.10.0->accelerate) (1.11.1)
# Requirement already satisfied: networkx in c:\users\platinum\anaconda3\envs\cuda_venv\lib\site-packages (from torch>=1.10.0->accelerate) (3.1)
# Requirement already satisfied: jinja2 in c:\users\platinum\anaconda3\envs\cuda_venv\lib\site-packages (from torch>=1.10.0->accelerate) (3.1.2)
# Requirement already satisfied: colorama in c:\users\platinum\anaconda3\envs\cuda_venv\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\platinum\appdata\roaming\python\python311\site-packages (from matplotlib->mediapipe) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\platinum\appdata\roaming\python\python311\site-packages (from matplotlib->mediapipe) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\platinum\appdata\roaming\python\python311\site-packages (from matplotlib->mediapipe) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\platinum\appdata\roaming\python\python311\site-packages (from matplotlib->mediapipe) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\platinum\anaconda3\envs\cuda_venv\lib\site-packages (from matplotlib->mediapipe) (10.0.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\platinum\anaconda3\envs\cuda_venv\lib\site-packages (from matplotlib->mediapipe) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\platinum\anaconda3\envs\cuda_venv\lib\site-packages (from matplotlib->mediapipe) (2.8.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\platinum\anaconda3\envs\cuda_venv\lib\site-packages (from requests->transformers) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\platinum\anaconda3\envs\cuda_venv\lib\site-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\platinum\anaconda3\envs\cuda_venv\lib\site-packages (from requests->transformers) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\platinum\anaconda3\envs\cuda_venv\lib\site-packages (from requests->transformers) (2023.7.22)
# Requirement already satisfied: pycparser in c:\users\platinum\anaconda3\envs\cuda_venv\lib\site-packages (from CFFI>=1.0->sounddevice>=0.4.4->mediapipe) (2.21)
# Requirement already satisfied: six>=1.5 in c:\users\platinum\anaconda3\envs\cuda_venv\lib\site-packages (from python-dateutil>=2.7->matplotlib->mediapipe) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\platinum\anaconda3\envs\cuda_venv\lib\site-packages (from jinja2->torch>=1.10.0->accelerate) (2.1.1)
# Requirement already satisfied: mpmath>=0.19 in c:\users\platinum\anaconda3\envs\cuda_venv\lib\site-packages (from sympy->torch>=1.10.0->accelerate) (1.3.0)
# Downloading huggingface_hub-0.17.3-py3-none-any.whl (295 kB)
#    ---------------------------------------- 0.0/295.0 kB ? eta -:--:--
#    ---------------------------------------- 0.0/295.0 kB ? eta -:--:--
#    ---------------------------------------- 0.0/295.0 kB ? eta -:--:--
#    ---------------------------------------- 0.0/295.0 kB ? eta -:--:--
#    - -------------------------------------- 10.2/295.0 kB ? eta -:--:--
#    - -------------------------------------- 10.2/295.0 kB ? eta -:--:--
#    - -------------------------------------- 10.2/295.0 kB ? eta -:--:--
#    - -------------------------------------- 10.2/295.0 kB ? eta -:--:--
#    - -------------------------------------- 10.2/295.0 kB ? eta -:--:--
#    - -------------------------------------- 10.2/295.0 kB ? eta -:--:--
#    - -------------------------------------- 10.2/295.0 kB ? eta -:--:--
#    - -------------------------------------- 10.2/295.0 kB ? eta -:--:--
#    - -------------------------------------- 10.2/295.0 kB ? eta -:--:--
#    - -------------------------------------- 10.2/295.0 kB ? eta -:--:--
#    - -------------------------------------- 10.2/295.0 kB ? eta -:--:--
#    - -------------------------------------- 10.2/295.0 kB ? eta -:--:--
#    - -------------------------------------- 10.2/295.0 kB ? eta -:--:--
#    - -------------------------------------- 10.2/295.0 kB ? eta -:--:--
#    - -------------------------------------- 10.2/295.0 kB ? eta -:--:--
#    - -------------------------------------- 10.2/295.0 kB ? eta -:--:--
#    - -------------------------------------- 10.2/295.0 kB ? eta -:--:--
#    - -------------------------------------- 10.2/295.0 kB ? eta -:--:--
#    - -------------------------------------- 10.2/295.0 kB ? eta -:--:--
#    - -------------------------------------- 10.2/295.0 kB ? eta -:--:--
#    - -------------------------------------- 10.2/295.0 kB ? eta -:--:--
#    - -------------------------------------- 10.2/295.0 kB ? eta -:--:--
#    - -------------------------------------- 10.2/295.0 kB ? eta -:--:--
#    - -------------------------------------- 10.2/295.0 kB ? eta -:--:--
#    - -------------------------------------- 10.2/295.0 kB ? eta -:--:--
#    - -------------------------------------- 10.2/295.0 kB ? eta -:--:--
#    - -------------------------------------- 10.2/295.0 kB ? eta -:--:--
#    - -------------------------------------- 10.2/295.0 kB ? eta -:--:--
#    ----------- ---------------------------- 81.9/295.0 kB 53.9 kB/s eta 0:00:04
#    ----------- ---------------------------- 81.9/295.0 kB 53.9 kB/s eta 0:00:04
#    ----------- ---------------------------- 81.9/295.0 kB 53.9 kB/s eta 0:00:04
#    ----------- ---------------------------- 81.9/295.0 kB 53.9 kB/s eta 0:00:04
#    ----------- ---------------------------- 81.9/295.0 kB 53.9 kB/s eta 0:00:04
#    ----------- ---------------------------- 81.9/295.0 kB 53.9 kB/s eta 0:00:04
#    ----------- ---------------------------- 81.9/295.0 kB 53.9 kB/s eta 0:00:04
#    ----------- ---------------------------- 81.9/295.0 kB 53.9 kB/s eta 0:00:04
#    ----------- ---------------------------- 81.9/295.0 kB 53.9 kB/s eta 0:00:04
#    ----------- ---------------------------- 81.9/295.0 kB 53.9 kB/s eta 0:00:04
#    ----------- ---------------------------- 81.9/295.0 kB 53.9 kB/s eta 0:00:04
#    ------------ --------------------------- 92.2/295.0 kB 45.2 kB/s eta 0:00:05
#    ------------ --------------------------- 92.2/295.0 kB 45.2 kB/s eta 0:00:05
#    ------------ --------------------------- 92.2/295.0 kB 45.2 kB/s eta 0:00:05
#    ------------ --------------------------- 92.2/295.0 kB 45.2 kB/s eta 0:00:05
#    -------------- ------------------------ 112.6/295.0 kB 50.4 kB/s eta 0:00:04
#    -------------- ------------------------ 112.6/295.0 kB 50.4 kB/s eta 0:00:04
#    --------------------------------- ----- 256.0/295.0 kB 65.3 kB/s eta 0:00:01
#    ------------------------------------ -- 276.5/295.0 kB 66.8 kB/s eta 0:00:01
#    ------------------------------------ -- 276.5/295.0 kB 66.8 kB/s eta 0:00:01
#    ------------------------------------ -- 276.5/295.0 kB 66.8 kB/s eta 0:00:01
#    ------------------------------------ -- 276.5/295.0 kB 66.8 kB/s eta 0:00:01
#    --------------------------------------- 295.0/295.0 kB 68.5 kB/s eta 0:00:00
# Installing collected packages: huggingface-hub
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface-hub 0.21.4
#     Uninstalling huggingface-hub-0.21.4:
#       Successfully uninstalled huggingface-hub-0.21.4
# Successfully installed huggingface-hub-0.17.3
# Could not fetch URL https://pypi.ngc.nvidia.com/pip/: There was a problem confirming the ssl certificate: HTTPSConnectionPool(host='pypi.ngc.nvidia.com', port=443): Max retries exceeded with url: /pip/ (Caused by SSLError(SSLEOFError(8, '[SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1006)'))) - skipping
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# diffusers 0.28.0.dev0 requires huggingface-hub>=0.20.2, but you have huggingface-hub 0.17.3 which is incompatible.

# %%
from diffusers import StableDiffusionXLAdapterPipeline, T2IAdapter, EulerAncestralDiscreteScheduler, AutoencoderKL
from diffusers.utils import load_image, make_image_grid
from controlnet_aux.pidi import PidiNetDetector
import torch
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from diffusers import StableDiffusionXLAdapterPipeline, T2IAdapter, EulerAncestralDiscreteScheduler, AutoencoderKL
#       2 from diffusers.utils import load_image, make_image_grid
#       3 from controlnet_aux.pidi import PidiNetDetector
#
# File ~\anaconda3\envs\cuda_venv\Lib\site-packages\diffusers\__init__.py:5
#       1 __version__ = "0.22.0.dev0"
#       3 from typing import TYPE_CHECKING
# ----> 5 from .utils import (
#       6     DIFFUSERS_SLOW_IMPORT,
#       7     OptionalDependencyNotAvailable,
#       8     _LazyModule,
#       9     is_flax_available,
#      10     is_k_diffusion_available,
#      11     is_librosa_available,
#      12     is_note_seq_available,
#      13     is_onnx_available,
#      14     is_scipy_available,
#      15     is_torch_available,
#      16     is_torchsde_available,
#      17     is_transformers_available,
#      18 )
#      21 # Lazy Import based on
#      22 # https://github.com/huggingface/transformers/blob/main/src/transformers/__init__.py
#      23
#      24 # When adding a new object to this init, please add it to `_import_structure`. The `_import_structure` is a dictionary submodule to list of object names,
#      25 # and is used to defer the actual importing for when the objects are requested.
#      26 # This way `import diffusers` provides the names in the namespace without actually importing anything (and especially none of the backends).
#      28 _import_structure = {
#      29     "configuration_utils": ["ConfigMixin"],
#      30     "models": [],
#    (...)
#      50     ],
#      51 }
#
# File ~\anaconda3\envs\cuda_venv\Lib\site-packages\diffusers\utils\__init__.py:21
#      18 from packaging import version
#      20 from .. import __version__
# ---> 21 from .constants import (
#      22     CONFIG_NAME,
#      23     DEPRECATED_REVISION_ARGS,
#      24     DIFFUSERS_CACHE,
#      25     DIFFUSERS_DYNAMIC_MODULE_NAME,
#      26     FLAX_WEIGHTS_NAME,
#      27     HF_MODULES_CACHE,
#      28     HUGGINGFACE_CO_RESOLVE_ENDPOINT,
#      29     MIN_PEFT_VERSION,
#      30     ONNX_EXTERNAL_WEIGHTS_NAME,
#      31     ONNX_WEIGHTS_NAME,
#      32     SAFETENSORS_WEIGHTS_NAME,
#      33     USE_PEFT_BACKEND,
#      34     WEIGHTS_NAME,
#      35 )
#      36 from .deprecation_utils import deprecate
#      37 from .doc_utils import replace_example_docstring
#
# File ~\anaconda3\envs\cuda_venv\Lib\site-packages\diffusers\utils\constants.py:17
#      14 import importlib
#      15 import os
# ---> 17 from huggingface_hub.constants import HUGGINGFACE_HUB_CACHE, hf_cache_home
#      18 from packaging import version
#      20 from .import_utils import is_peft_available, is_transformers_available
#
# ImportError: cannot import name 'HF_HOME' from 'huggingface_hub.constants' (C:\Users\Platinum\anaconda3\envs\cuda_venv\Lib\site-packages\huggingface_hub\constants.py)

# %%
# load adapter
adapter = T2IAdapter.from_pretrained(
  "TencentARC/t2i-adapter-sketch-sdxl-1.0", torch_dtype=torch.float, varient="fp16"
).to("cpu")

# %%
# load euler_a scheduler
model_id = 'stabilityai/stable-diffusion-xl-base-1.0'
euler_a = EulerAncestralDiscreteScheduler.from_pretrained(model_id, subfolder="scheduler")
vae=AutoencoderKL.from_pretrained("madebyollin/sdxl-vae-fp16-fix", torch_dtype=torch.float)
pipe = StableDiffusionXLAdapterPipeline.from_pretrained(
    model_id, vae=vae, adapter=adapter, scheduler=euler_a, torch_dtype=torch.float, variant="fp16", 
).to("cpu")
#pipe.enable_xformers_memory_efficient_attention()

pidinet = PidiNetDetector.from_pretrained("lllyasviel/Annotators").to("cpu")
# Out:
# Loading pipeline components...: 100%|██████████| 7/7 [00:33<00:00,  4.82s/it]

# %%
url = "https://huggingface.co/Adapter/t2iadapter/resolve/main/figs_SDXLV1.0/org_sketch.png"
image = load_image(url)
image = pidinet(
  image, detect_resolution=1024, image_resolution=1024, apply_filter=True
)
prompt = "a robot, mount fuji in the background, 4k photo, highly detailed"
negative_prompt = "extra digit, fewer digits, cropped, worst quality, low quality, glitch, deformed, mutated, ugly, disfigured"

gen_images = pipe(
    prompt=prompt,
    negative_prompt=negative_prompt,
    image=image,
    num_inference_steps=30,
    adapter_conditioning_scale=0.9,
    guidance_scale=7.5, 
).images[0]
gen_images.save('out_sketch.png')
# Out:
# 100%|██████████| 30/30 [48:42<00:00, 97.41s/it]

# %%
image2 = load_image("tree.jpg")
image2 = pidinet(
  image2, detect_resolution=1024, image_resolution=1024, apply_filter=True
)
prompt = "a tree, mount in the background, 4k photo, highly detailed"
negative_prompt = ""

gen_images = pipe(
    prompt=prompt,
    negative_prompt=negative_prompt,
    image=image2,
    num_inference_steps=10,
    adapter_conditioning_scale=0.9,
    guidance_scale=7.5, 
).images[0]
gen_images.save('out_tree.png')
# Out:
# 100%|██████████| 10/10 [14:51<00:00, 89.19s/it]

# %%
image2 = load_image("manga.jpeg")
image2 = pidinet(
  image2, detect_resolution=1024, image_resolution=1024, apply_filter=True
)
prompt = "a manga, purple jacket, blonde, green eyes, 4k photo, highly detailed"
negative_prompt = ""

gen_images = pipe(
    prompt=prompt,
    negative_prompt=negative_prompt,
    image=image2,
    num_inference_steps=10,
    adapter_conditioning_scale=0.9,
    guidance_scale=7.5, 
).images[0]
gen_images.save('out_manga.png')
# Out:
# 100%|██████████| 10/10 [12:41<00:00, 76.14s/it]
